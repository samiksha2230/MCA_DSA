# %%
#Row-Major order representation
def demonstrate_row_major():
    matrix = [
        [8, 10],
        [11, 13],
        [14, 16]
    ]

    rows = 3
    cols = 2

    flat_memory = []

    print("Logical 2D Matrix View:")
    for r in matrix:
        print(r)
        for element in r:
            flat_memory.append(element)

    print("\nRow-Major Linear Representation in Memory:")
    print(flat_memory)


# Function call
demonstrate_row_major()
# Out:
# Logical 2D Matrix View:
# [8, 10]
# [11, 13]
# [14, 16]
#
# Row-Major Linear Representation in Memory:
# [8, 10, 11, 13, 14, 16]

# %%
arr=[
 
        [8, 10],
        [11, 13],
        [14, 16]   
]
print("elements in row major order:")

for i in range(len(arr)):
    for j in range(len(arr[i])):
        print(arr[i][j], end=" ")
# Out:
# elements in row major order:
# 8 10 11 13 14 16
