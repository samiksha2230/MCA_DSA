# %%
n1 = {"data": 10, "next": None}
n2 = {"data": 20, "next": None}
n3 = {"data": 30, "next": None}

# Linking nodes
n1["next"] = n2
n2["next"] = n3

head = n1

temp = head
while temp:
    print(temp["data"], end=" -> ")
    temp = temp["next"]
# Out:
# 10 -> 20 -> 30 ->
